# %% [markdown]
# <a href="https://colab.research.google.com/github/seleznevs79/PythonHW10/blob/main/PythonHW10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## Задача 44:
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в **one hot** вид. Сможете ли вы это сделать без
# get_dummies?

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(20)
# Out:
#    whoAmI
# 0   robot
# 1   human
# 2   human
# 3   robot
# 4   human
# 5   human
# 6   human
# 7   robot
# 8   robot
# 9   human
# 10  human
# 11  human
# 12  robot
# 13  robot
# 14  human
# 15  human
# 16  robot
# 17  robot
# 18  robot
# 19  robot

# %%
data.loc[data['whoAmI'] == 'robot', 'robot'] = '1'
data.loc[data['whoAmI'] != 'robot', 'robot'] = '0'
data.loc[data['whoAmI'] == 'human', 'human'] = '1'
data.loc[data['whoAmI'] != 'human', 'human'] = '0'
data.head(20)
# Out:
#    whoAmI robot human
# 0   robot     1     0
# 1   human     0     1
# 2   human     0     1
# 3   robot     1     0
# 4   human     0     1
# 5   human     0     1
# 6   human     0     1
# 7   robot     1     0
# 8   robot     1     0
# 9   human     0     1
# 10  human     0     1
# 11  human     0     1
# 12  robot     1     0
# 13  robot     1     0
# 14  human     0     1
# 15  human     0     1
# 16  robot     1     0
# 17  robot     1     0
# 18  robot     1     0
# 19  robot     1     0
